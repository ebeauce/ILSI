# %% [markdown]
# # Synthetic experiments presented in Beauce et al. 2021

# %%
import os
import sys

# import the iterative linear stress inversion package
import ILSI

import numpy as np
import h5py as h5
import matplotlib.pyplot as plt
from time import time as give_time

from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import matplotlib.colorbar as clb
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable

import mplstereonet

# set plotting parameters
import seaborn as sns
sns.set()
sns.set_style('ticks')
sns.set_palette('colorblind')
plt.rcParams['savefig.dpi'] = 200
plt.rcParams['svg.fonttype'] = 'none'

# define the color palette
_colors_ = ['C0', 'C2', 'C1', 'C4']

# %% [markdown]
# ## Run the stress inversions
#
# We first define the main routine that runs the stress inversion with different methods, on different levels of noise in the data. The routine can either run experiment #1 or experiment #2, as shown in the paper.
# The stress inversion parameters I provide are those that I used in the paper. They make the code runs for quite a long time, and you might want to decrease n_resamplings to a much lower value (from 1000 to 50, for example).<br>
#
# Running one experiment with the stress inversion parameters I provide takes a ~ 2h on my laptop.

# %%
def main(experiment=1):
    """
    experiment is 1 or 2.
    """
    t_start_experiment = give_time()
    # --------------------------------------
    #   synthetic experiment parameters
    # --------------------------------------
    # fault plane parameters
    n_earthquakes = 100
    np.random.seed(0)
    rakes = []
    if experiment == 1:
        # -------- experiment #1 ------------
        strike_mean, strike_std = 110., 10.
        dip_min, dip_max = 65., 90.
        strikes = np.random.normal(loc=strike_mean, scale=strike_std, size=n_earthquakes)
        dips = np.random.uniform(low=dip_min, high=dip_max, size=n_earthquakes)
        # stress tensor in the (north, west, upward) coordinate system
        sig1 = np.array([-1./np.sqrt(2.), -1./np.sqrt(2.), 0.])
        sig2 = np.array([0., 0., +1.])
        sig3 = np.array([-1./np.sqrt(2.), 1./np.sqrt(2.), 0.])
        R = 0.50
    elif experiment == 2:
        # -------- experiment #2 ------------
        strike_mean, strike_std = 110., 10.
        dip_min, dip_max = 20., 65.
        strikes = np.random.normal(loc=strike_mean, scale=strike_std, size=n_earthquakes)
        dips = np.random.uniform(low=dip_min, high=dip_max, size=n_earthquakes)
        # stress tensor in the (north, west, upward) coordinate system
        sig1 = np.array([-1./np.sqrt(2.), -1./np.sqrt(2.), 0.])
        sig2 = np.array([0., 0., +1.])
        sig3 = np.array([-1./np.sqrt(2.), 1./np.sqrt(2.), 0.])
        V = np.stack((sig1, sig2, sig3), axis=1)
        # do the rotation in the eigenbasis:
        # rotate 45 degrees around sig3
        unit_vectors = np.identity(3)
        rot = rotation_x3(45.)
        unit_vectors = np.dot(rot, unit_vectors)
        # take these vectors back to the original frame (north, west, upward)
        new_principal_directions = np.dot(unit_vectors, V.T)
        sig1 = new_principal_directions[:, 0]
        sig2 = new_principal_directions[:, 1]
        sig3 = new_principal_directions[:, 2]
        R = 0.70
    # -------------------
    # tension positive
    V = np.stack((sig1, sig2, sig3), axis=1)
    s1, s2, s3 = -1., 2*R-1., +1.
    S = np.diag(np.array([s1, s2, s3]) - np.sum([s1, s2, s3])/3.)
    S /= np.sqrt(np.sum(S**2))
    true_stress_tensor = np.dot(V, np.dot(S, V.T))
    # eigenvalue decomposition
    true_princ_stresses, true_princ_dir = \
            ILSI.utils_stress.stress_tensor_eigendecomposition(true_stress_tensor)
    print('True stress tensor:\n', true_stress_tensor)
    print('The directions of the principal stresses are:')
    for i, label in enumerate(['Most compressive', 'Intermediate', 'Least compressive']):
        print('{} stress: Azimuth={:.2f}, plunge={:.2f}'.
                format(label, ILSI.utils_stress.get_bearing_plunge(true_princ_dir[:, i])[0],
                       ILSI.utils_stress.get_bearing_plunge(true_princ_dir[:, i])[1]))
    for i in range(len(strikes)):
        # give fake rake, we only want the normal
        n, _ = ILSI.utils_stress.normal_slip_vectors(strikes[i], dips[i], 0.)
        traction = np.dot(true_stress_tensor, n.T) 
        normal_traction = np.sum(traction.squeeze()*n.squeeze(), axis=-1)*n.T
        shear_traction = traction - normal_traction
        shear_dir = shear_traction/np.sqrt(np.sum(shear_traction**2))
        # find the rake that will make slip in the same direction as shear
        s, d, r = ILSI.utils_stress.strike_dip_rake(n, shear_dir)
        rakes.append(r)
    rakes = np.float32(rakes)%360.
    # generate noisy focal mechanisms
    noise = [0., 3., 10.]
    strikes_1 = np.zeros((n_earthquakes, len(noise)), dtype=np.float32)
    dips_1 = np.zeros((n_earthquakes, len(noise)), dtype=np.float32)
    rakes_1 = np.zeros((n_earthquakes, len(noise)), dtype=np.float32)
    strikes_2 = np.zeros((n_earthquakes, len(noise)), dtype=np.float32)
    dips_2 = np.zeros((n_earthquakes, len(noise)), dtype=np.float32)
    rakes_2 = np.zeros((n_earthquakes, len(noise)), dtype=np.float32)
    for i in range(n_earthquakes):
        for n in range(len(noise)):
            s1 = strikes[i] + np.random.uniform(low=-noise[n], high=noise[n])
            d1 = np.random.uniform(low=max(0., dips[i]-noise[n]), high=min(90., dips[i]+noise[n]))
            r1 = rakes[i] + np.random.uniform(low=-noise[n], high=noise[n])
            strikes_1[i, n], dips_1[i, n], rakes_1[i, n] =\
                    s1, d1, r1
            s2, d2, r2 = ILSI.utils_stress.aux_plane(
                    strikes_1[i, n], dips_1[i, n], rakes_1[i, n])
            strikes_2[i, n], dips_2[i, n], rakes_2[i, n] =\
                    s2, d2, r2
    # make sure the parameters fall into the correct range
    strikes_1, rakes_1 = strikes_1%360., rakes_1%360. 
    strikes_2, rakes_2 = strikes_2%360., rakes_2%360.
    print('-------------')
    # --------------------------------------
    #  shear tractions on the planes defined by
    #  the noisy focal mechanisms
    # --------------------------------------
    shear_tractions = np.zeros((n_earthquakes, len(noise), 3), dtype=np.float32)
    slip_vectors = np.zeros((len(noise), n_earthquakes, 3), dtype=np.float32)
    for n in range(len(noise)):
        for i in range(n_earthquakes):
            n_, d_ = ILSI.utils_stress.normal_slip_vectors(
                    strikes_1[i, n], dips_1[i, n], rakes_1[i, n])
            _, _, shear_tractions[i, n, :] = ILSI.utils_stress.compute_traction(
                    true_stress_tensor, n_.reshape(1, 3))
            slip_vectors[n, i, :] = d_
    print('Normalized shear traction on true faults using the true stress tensor:')
    print(np.sqrt(np.sum(shear_tractions[:, 0, :]**2, axis=-1)))
    # --------------------------------
    #    stress tensor inversion
    # --------------------------------
    # inversion parameter
    friction_min = 0.1
    friction_max = 0.8
    friction_step = 0.05
    n_random_selections = 30
    n_stress_iter = 20
    n_averaging = 5
    n_resamplings = 1000
    #n_resamplings = 10
    ILSI_kwargs = {}
    ILSI_kwargs['max_n_iterations'] = 1000
    ILSI_kwargs['shear_update_atol'] = 1.e-7
    Tarantola_kwargs0 = {}
    inversion_output = {}
    methods = ['linear', 'failure_criterion', 'iterative',
               'iterative_failure_criterion']
    # --------------------------------
    # initialize output dictionary
    # --------------------------------
    for method in methods:
        inversion_output[method] = {}
        inversion_output[method]['stress_tensor'] =\
                np.zeros((len(noise), 3, 3), dtype=np.float32)
        inversion_output[method]['principal_stresses'] =\
                np.zeros((len(noise), 3), dtype=np.float32)
        inversion_output[method]['principal_directions'] =\
                np.zeros((len(noise), 3, 3), dtype=np.float32)
        inversion_output[method]['misfit'] = np.zeros(len(noise), dtype=np.float32)
        inversion_output[method]['boot_stress_tensor'] =\
                np.zeros((len(noise), n_resamplings, 3, 3), dtype=np.float32)
        inversion_output[method]['boot_principal_stresses'] =\
                np.zeros((len(noise), n_resamplings, 3), dtype=np.float32)
        inversion_output[method]['boot_principal_directions'] =\
                np.zeros((len(noise), n_resamplings, 3, 3), dtype=np.float32)
        inversion_output[method]['boot_misfit'] = np.zeros((len(noise), n_resamplings), dtype=np.float32)
    inversion_output['iterative_failure_criterion']['friction'] =\
            np.zeros(len(noise), dtype=np.float32)
    inversion_output['failure_criterion']['friction'] =\
            np.zeros(len(noise), dtype=np.float32)
    for experiment in ['true_fp_linear', 'true_fp_iterative']:
        inversion_output[experiment] = {}
        inversion_output[experiment]['stress_tensor'] =\
                np.zeros((3, 3), dtype=np.float32)
        inversion_output[experiment]['principal_stresses'] =\
                np.zeros(3, dtype=np.float32)
        inversion_output[experiment]['principal_directions'] =\
                np.zeros((3, 3), dtype=np.float32)
        inversion_output[experiment]['misfit'] = np.zeros(len(noise), dtype=np.float32)
        inversion_output[experiment]['boot_stress_tensor'] =\
                np.zeros((n_resamplings, 3, 3), dtype=np.float32)
        inversion_output[experiment]['boot_principal_stresses'] =\
                np.zeros((n_resamplings, 3), dtype=np.float32)
        inversion_output[experiment]['boot_principal_directions'] =\
                np.zeros((n_resamplings, 3, 3), dtype=np.float32)
        inversion_output[experiment]['boot_misfit'] = np.zeros((n_resamplings, len(noise)), dtype=np.float32)
    # -----------------------------------------
    # first, test the two inversion schemes on the true fault planes
    # ----------- whole data set
    inversion_output['true_fp_linear']['stress_tensor'],\
    inversion_output['true_fp_linear']['principal_stresses'],\
    inversion_output['true_fp_linear']['principal_directions'] =\
               ILSI.ilsi.Michael1984_inversion(
                       strikes, dips, rakes,
                       return_eigen=True, return_stats=False,
                       Tarantola_kwargs=Tarantola_kwargs0)
    inversion_output['true_fp_linear']['misfit'] =\
            np.mean(ILSI.utils_stress.mean_angular_residual(
                inversion_output['true_fp_linear']['stress_tensor'],
                strikes, dips, rakes))
    inversion_output['true_fp_iterative']['stress_tensor'], _,\
    inversion_output['true_fp_iterative']['principal_stresses'],\
    inversion_output['true_fp_iterative']['principal_directions'] =\
               ILSI.ilsi.iterative_linear_si(
                       strikes, dips, rakes,
                       return_eigen=True, return_stats=False,
                       Tarantola_kwargs=Tarantola_kwargs0, **ILSI_kwargs)
    inversion_output['true_fp_iterative']['misfit'] =\
            np.mean(ILSI.utils_stress.mean_angular_residual(
                inversion_output['true_fp_iterative']['stress_tensor'],
                strikes, dips, rakes))
    # ----------- bootstrapped data set
    for b in range(n_resamplings):
        bootstrapped_set = np.random.choice(
                np.arange(n_earthquakes), replace=True, size=n_earthquakes)
        strikes_b, dips_b, rakes_b = strikes[bootstrapped_set], dips[bootstrapped_set], rakes[bootstrapped_set]
        inversion_output['true_fp_linear']['boot_stress_tensor'][b, ...],\
        inversion_output['true_fp_linear']['boot_principal_stresses'][b, ...],\
        inversion_output['true_fp_linear']['boot_principal_directions'][b, ...] =\
                   ILSI.ilsi.Michael1984_inversion(
                           strikes_b, dips_b, rakes_b,
                           return_eigen=True, return_stats=False,
                           Tarantola_kwargs=Tarantola_kwargs0)
        inversion_output['true_fp_linear']['boot_misfit'][b, ...] =\
                np.mean(ILSI.utils_stress.mean_angular_residual(
                    inversion_output['true_fp_linear']['boot_stress_tensor'][b, ...],
                    strikes_b, dips_b, rakes_b))
        inversion_output['true_fp_iterative']['boot_stress_tensor'][b, ...], _,\
        inversion_output['true_fp_iterative']['boot_principal_stresses'][b, ...],\
        inversion_output['true_fp_iterative']['boot_principal_directions'][b, ...] =\
                   ILSI.ilsi.iterative_linear_si(
                           strikes_b, dips_b, rakes_b,
                           return_eigen=True, return_stats=False,
                           Tarantola_kwargs=Tarantola_kwargs0, **ILSI_kwargs)
        inversion_output['true_fp_iterative']['boot_misfit'][b, ...] =\
                np.mean(ILSI.utils_stress.mean_angular_residual(
                    inversion_output['true_fp_iterative']['boot_stress_tensor'][b, ...],
                    strikes_b, dips_b, rakes_b))
    # --------------------------------------------
    #   now, apply each method on the focal mechanism data set
    # --------------------------------------------
    Tarantola_kwargs = {}
    for n in range(len(noise)):
        Tarantola_kwargs['noise{:d}'.format(n)] = Tarantola_kwargs0.copy()
        print(f'Noise level {n}, linear inversion...')
        # simple, linear inversion
        inversion_output['linear']['stress_tensor'][n, ...],\
        inversion_output['linear']['principal_stresses'][n, ...],\
        inversion_output['linear']['principal_directions'][n, ...] =\
                ILSI.ilsi.inversion_one_set(
                        strikes_1[:, n], dips_1[:, n], rakes_1[:, n],
                        n_random_selections=n_random_selections,
                        **ILSI_kwargs,
                        Tarantola_kwargs=Tarantola_kwargs['noise{:d}'.format(n)],
                        iterative_method=False)
        print(f'Noise level {n}, linear iterative inversion...')
        # linear inversion for both the stress tensor and shear stresses
        inversion_output['iterative']['stress_tensor'][n, ...],\
        inversion_output['iterative']['principal_stresses'][n, ...],\
        inversion_output['iterative']['principal_directions'][n, ...] =\
                ILSI.ilsi.inversion_one_set(
                        strikes_1[:, n], dips_1[:, n], rakes_1[:, n],
                        n_random_selections=n_random_selections,
                        **ILSI_kwargs,
                        Tarantola_kwargs=Tarantola_kwargs['noise{:d}'.format(n)],
                        iterative_method=True)
        print(f'Noise level {n}, failure criterion inversion...')
        inversion_output['failure_criterion']['stress_tensor'][n, ...],\
        inversion_output['failure_criterion']['friction'][n],\
        inversion_output['failure_criterion']['principal_stresses'][n, ...],\
        inversion_output['failure_criterion']['principal_directions'][n, ...] =\
                ILSI.ilsi.inversion_one_set_instability(
                        strikes_1[:, n], dips_1[:, n], rakes_1[:, n],
                        n_random_selections=n_random_selections,
                        **ILSI_kwargs,
                        Tarantola_kwargs=Tarantola_kwargs['noise{:d}'.format(n)],
                        friction_min=friction_min,
                        friction_max=friction_max,
                        friction_step=friction_step,
                        n_stress_iter=n_stress_iter,
                        n_averaging=n_averaging,
                        iterative_method=False)
        print(f'Noise level {n}, Linear iterative and failure '
              'criterion inversion...')
        inversion_output['iterative_failure_criterion']['stress_tensor'][n, ...],\
        inversion_output['iterative_failure_criterion']['friction'][n],\
        inversion_output['iterative_failure_criterion']['principal_stresses'][n, ...],\
        inversion_output['iterative_failure_criterion']['principal_directions'][n, ...] =\
                ILSI.ilsi.inversion_one_set_instability(
                        strikes_1[:, n], dips_1[:, n], rakes_1[:, n],
                        n_random_selections=n_random_selections,
                        **ILSI_kwargs,
                        Tarantola_kwargs=Tarantola_kwargs['noise{:d}'.format(n)],
                        friction_min=friction_min,
                        friction_max=friction_max,
                        friction_step=friction_step,
                        n_stress_iter=n_stress_iter,
                        n_averaging=n_averaging,
                        plot=False)
        for method in methods:
            inversion_output[method]['misfit'][n] =\
                    np.mean(ILSI.utils_stress.mean_angular_residual(
                        inversion_output[method]['stress_tensor'][n, ...],
                        strikes, dips, rakes))
        print(f'Noise level {n}, linear inversion (bootstrapping)...')
        # simple, linear inversion
        inversion_output['linear']['boot_stress_tensor'][n, ...],\
        inversion_output['linear']['boot_principal_stresses'][n, ...],\
        inversion_output['linear']['boot_principal_directions'][n, ...] =\
                ILSI.ilsi.inversion_bootstrap(
                        strikes_1[:, n], dips_1[:, n], rakes_1[:, n],
                        n_resamplings=n_resamplings,
                        Tarantola_kwargs=Tarantola_kwargs['noise{:d}'.format(n)],
                        iterative_method=False)
        print(f'Noise level {n}, Linear iterative inversion (bootstrapping)...')
        # Linear inversion for both the stress tensor and shear stresses
        inversion_output['iterative']['boot_stress_tensor'][n, ...],\
        inversion_output['iterative']['boot_principal_stresses'][n, ...],\
        inversion_output['iterative']['boot_principal_directions'][n, ...] =\
                ILSI.ilsi.inversion_bootstrap(
                        strikes_1[:, n], dips_1[:, n], rakes_1[:, n],
                        n_resamplings=n_resamplings,
                        **ILSI_kwargs,
                        Tarantola_kwargs=Tarantola_kwargs['noise{:d}'.format(n)],
                        iterative_method=True)
        print(f'Noise level {n}, failure criterion inversion (bootstrapping)...')
        inversion_output['failure_criterion']['boot_stress_tensor'][n, ...],\
        inversion_output['failure_criterion']['boot_principal_stresses'][n, ...],\
        inversion_output['failure_criterion']['boot_principal_directions'][n, ...] =\
                ILSI.ilsi.inversion_bootstrap_instability(
                        inversion_output['failure_criterion']['principal_directions'][n, ...],
                        ILSI.utils_stress.R_(inversion_output['failure_criterion']['principal_stresses'][n, ...]),
                        strikes_1[:, n], dips_1[:, n], rakes_1[:, n],
                        inversion_output['failure_criterion']['friction'][n],
                        **ILSI_kwargs,
                        Tarantola_kwargs=Tarantola_kwargs['noise{:d}'.format(n)],
                        n_stress_iter=n_stress_iter,
                        n_resamplings=n_resamplings,
                        iterative_method=False, verbose=0)
        print(f'Noise level {n}, non-linear iterative and failure '
              'criterion inversion (bootstrapping)...')
        inversion_output['iterative_failure_criterion']['boot_stress_tensor'][n, ...],\
        inversion_output['iterative_failure_criterion']['boot_principal_stresses'][n, ...],\
        inversion_output['iterative_failure_criterion']['boot_principal_directions'][n, ...] =\
                ILSI.ilsi.inversion_bootstrap_instability(
                        inversion_output['iterative_failure_criterion']['principal_directions'][n, ...],
                        ILSI.utils_stress.R_(inversion_output['iterative_failure_criterion']['principal_stresses'][n, ...]),
                        strikes_1[:, n], dips_1[:, n], rakes_1[:, n],
                        inversion_output['iterative_failure_criterion']['friction'][n],
                        **ILSI_kwargs,
                        Tarantola_kwargs=Tarantola_kwargs['noise{:d}'.format(n)],
                        n_stress_iter=n_stress_iter,
                        n_resamplings=n_resamplings,
                        iterative_method=True, verbose=0)
        for method in methods:
            for b in range(n_resamplings):
                inversion_output[method]['boot_misfit'][n, b] =\
                        np.mean(ILSI.utils_stress.mean_angular_residual(
                            inversion_output[method]['boot_stress_tensor'][n, b, ...],
                            strikes, dips, rakes))
    inversion_output['strikes'] = np.stack((strikes_1, strikes_2), axis=2)
    inversion_output['dips'] = np.stack((dips_1, dips_2), axis=2)
    inversion_output['rakes'] = np.stack((rakes_1, rakes_2), axis=2)
    t_end_experiment = give_time()
    print('Done! The experiment ran in {:.2f} seconds'.
         format(t_end_experiment-t_start_experiment))
    return true_stress_tensor, inversion_output

# %%
def rotation_x1(theta):
    theta = theta*np.pi/180.
    R = np.array([[1., 0., 0.],
                  [0., np.cos(theta), -np.sin(theta)],
                  [0., np.sin(theta), np.cos(theta)]])
    return R

def rotation_x3(theta):
    theta = theta*np.pi/180.
    R = np.array([[np.cos(theta), -np.sin(theta), 0.],
                  [np.sin(theta), np.cos(theta), 0.],
                  [0., 0., 1.]])
    return R

def save_results(true_stress_tensor, inversion_output, filename):
    import h5py as h5
    with h5.File(filename, mode='w') as f:
        for key1 in inversion_output.keys():
            if isinstance(inversion_output[key1], dict):
                f.create_group(key1)
                for key2 in inversion_output[key1].keys():
                    f[key1].create_dataset(key2, data=inversion_output[key1][key2])
            else:
                f.create_dataset(key1, data=inversion_output[key1])
        f.create_dataset('true_stress_tensor', data=true_stress_tensor)

def read_results(filename):
    import h5py as h5
    inversion_output = {}
    with h5.File(filename, mode='r') as f:
        for key1 in f.keys():
            if isinstance(f[key1], h5.Dataset):
                inversion_output[key1] = f[key1][()]
            else:
                inversion_output[key1] = {}
                for key2 in f[key1].keys():
                    inversion_output[key1][key2] = f[key1][key2][()]
    return inversion_output['true_stress_tensor'], inversion_output

# %%
# choose which experiment to run
experiment = 1

# %%
# run the experiment
true_stress_tensor, inversion_output = main(experiment=experiment)
# Out:
# True stress tensor:
#  [[ 0.14927744 -0.44783233 -0.34102415]
#  [-0.44783233  0.14927744 -0.34102415]
#  [-0.34102415 -0.34102415 -0.29855489]]
# The directions of the principal stresses are:
# Most compressive stress: Azimuth=135.00, plunge=45.00
# Intermediate stress: Azimuth=315.00, plunge=45.00
# Least compressive stress: Azimuth=225.00, plunge=0.00
# -------------
# Normalized shear traction on true faults using the true stress tensor:
# [0.53545046 0.3848568  0.51358074 0.5659766  0.48813942 0.40117484
#  0.42535836 0.40846577 0.47669727 0.4766065  0.3791944  0.47625807
#  0.42613974 0.3428102  0.3693372  0.44071394 0.34549195 0.42380393
#  0.4380136  0.2070569  0.19687541 0.36407012 0.51293087 0.20581385
#  0.50507843 0.24099922 0.48095044 0.22927792 0.53570205 0.46948105
#  0.48772007 0.2721326  0.21906342 0.23256658 0.40233642 0.49154618
#  0.4176796  0.4942785  0.27494934 0.2248879  0.21677937 0.20545882
#  0.4435334  0.5517833  0.26367435 0.45738074 0.29782984 0.50989133
#  0.39701205 0.48373786 0.22203806 0.48681703 0.41145617 0.2114348
#  0.30846706 0.5004324  0.48000005 0.3708051  0.31793424 0.4477429
#  0.20500022 0.32272398 0.32217985 0.2404724  0.31268388 0.42752564
#  0.3231889  0.49197906 0.43335935 0.2126341  0.35405943 0.40750942
#  0.5204895  0.39845243 0.4993684  0.37037683 0.40043044 0.2726768
#  0.41402474 0.47765902 0.45628798 0.5135329  0.359209   0.30652016
#  0.49456617 0.38757995 0.26057938 0.46096224 0.25412604 0.5143005
#  0.47837678 0.3897365  0.4608969  0.49397233 0.3885881  0.30684313
#  0.34450924 0.38862893 0.46586904 0.298278  ]
# /home/eric/miniconda3/envs/default/lib/python3.7/site-packages/ILSI/utils_stress.py:575: RuntimeWarning: invalid value encountered in arccos
#   angle = np.arccos(np.sum(d.squeeze()*shear_dir.squeeze()))
# Noise level 0, linear inversion...
# Noise level 0, linear iterative inversion...
# Noise level 0, failure criterion inversion...
# -------- 1/5 ----------
# Initial shape ratio: 0.48
# ----------
# Stress tensor difference at iteration 0: 0.13740241997615274.
# R=0.66, friction=0.60
# Total instability: 0.95/Total differential instability: 0.21
# Average angle: 10.53
# Squared residuals: 3.94e-03
# ----------
# Stress tensor difference at iteration 1: 0.16077585670453323.
# R=0.70, friction=0.60
# Total instability: 0.91/Total differential instability: 0.21
# Average angle: 11.24
# Squared residuals: 3.42e-03
# ----------
# Stress tensor difference at iteration 2: 0.4796918365237092.
# R=0.49, friction=0.60
# Total instability: 0.83/Total differential instability: 0.12
# Average angle: 12.91
# Squared residuals: 6.62e-03
# ----------
# Stress tensor difference at iteration 3: 0.2290933680129797.
# R=0.57, friction=0.60
# Total instability: 0.96/Total differential instability: 0.22
# Average angle: 9.53
# Squared residuals: 3.54e-03
# ----------
# Stress tensor difference at iteration 4: 0.3469006673772966.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 5: 0.5546278525604841.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 6: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 7: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 8: 0.5546278061156524.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 9: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 10: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 11: 0.5546278061156524.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 12: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 13: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 14: 0.5546278061156524.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 15: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 16: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 17: 0.5546278061156524.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 18: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 19: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# Did not converge, return best (R=0.68)
# -------- 2/5 ----------
# Initial shape ratio: 0.48
# ----------
# Stress tensor difference at iteration 0: 0.14054281931081777.
# R=0.66, friction=0.60
# Total instability: 0.95/Total differential instability: 0.21
# Average angle: 10.53
# Squared residuals: 3.94e-03
# ----------
# Stress tensor difference at iteration 1: 0.16077585670453323.
# R=0.70, friction=0.60
# Total instability: 0.91/Total differential instability: 0.21
# Average angle: 11.24
# Squared residuals: 3.42e-03
# ----------
# Stress tensor difference at iteration 2: 0.4796918365237092.
# R=0.49, friction=0.60
# Total instability: 0.83/Total differential instability: 0.12
# Average angle: 12.91
# Squared residuals: 6.62e-03
# ----------
# Stress tensor difference at iteration 3: 0.2290933680129797.
# R=0.57, friction=0.60
# Total instability: 0.96/Total differential instability: 0.22
# Average angle: 9.53
# Squared residuals: 3.54e-03
# ----------
# Stress tensor difference at iteration 4: 0.3469006673772966.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 5: 0.5546278525604841.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 6: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 7: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 8: 0.5546278061156524.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 9: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 10: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 11: 0.5546278061156524.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 12: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 13: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 14: 0.5546278061156524.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 15: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 16: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 17: 0.5546278061156524.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 18: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 19: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# Did not converge, return best (R=0.68)
# -------- 3/5 ----------
# Initial shape ratio: 0.46
# ----------
# Stress tensor difference at iteration 0: 0.1483221727446543.
# R=0.65, friction=0.60
# Total instability: 0.95/Total differential instability: 0.21
# Average angle: 10.42
# Squared residuals: 3.90e-03
# ----------
# Stress tensor difference at iteration 1: 0.17590223516478246.
# R=0.70, friction=0.60
# Total instability: 0.92/Total differential instability: 0.22
# Average angle: 11.24
# Squared residuals: 3.42e-03
# ----------
# Stress tensor difference at iteration 2: 0.47969183702932466.
# R=0.49, friction=0.60
# Total instability: 0.83/Total differential instability: 0.12
# Average angle: 12.91
# Squared residuals: 6.62e-03
# ----------
# Stress tensor difference at iteration 3: 0.22909336801298014.
# R=0.57, friction=0.60
# Total instability: 0.96/Total differential instability: 0.22
# Average angle: 9.53
# Squared residuals: 3.54e-03
# ----------
# Stress tensor difference at iteration 4: 0.34690066737729325.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 5: 0.5546278525604806.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 6: 0.2566926686026205.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 7: 0.354604008658556.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 8: 0.5546278061156523.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 9: 0.2566926686026205.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 10: 0.354604008658556.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 11: 0.5546278061156523.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 12: 0.2566926686026205.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 13: 0.354604008658556.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 14: 0.5546278061156523.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 15: 0.2566926686026205.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 16: 0.354604008658556.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 17: 0.5546278061156523.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 18: 0.2566926686026205.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 19: 0.354604008658556.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# Did not converge, return best (R=0.68)
# -------- 4/5 ----------
# Initial shape ratio: 0.48
# ----------
# Stress tensor difference at iteration 0: 0.14176564814265755.
# R=0.66, friction=0.60
# Total instability: 0.95/Total differential instability: 0.21
# Average angle: 10.53
# Squared residuals: 3.94e-03
# ----------
# Stress tensor difference at iteration 1: 0.16077585670453323.
# R=0.70, friction=0.60
# Total instability: 0.91/Total differential instability: 0.21
# Average angle: 11.24
# Squared residuals: 3.42e-03
# ----------
# Stress tensor difference at iteration 2: 0.4796918365237092.
# R=0.49, friction=0.60
# Total instability: 0.83/Total differential instability: 0.12
# Average angle: 12.91
# Squared residuals: 6.62e-03
# ----------
# Stress tensor difference at iteration 3: 0.2290933680129797.
# R=0.57, friction=0.60
# Total instability: 0.96/Total differential instability: 0.22
# Average angle: 9.53
# Squared residuals: 3.54e-03
# ----------
# Stress tensor difference at iteration 4: 0.3469006673772966.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 5: 0.5546278525604841.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 6: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 7: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 8: 0.5546278061156524.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 9: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 10: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 11: 0.5546278061156524.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 12: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 13: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 14: 0.5546278061156524.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 15: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 16: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 17: 0.5546278061156524.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 18: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 19: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# Did not converge, return best (R=0.68)
# -------- 5/5 ----------
# Initial shape ratio: 0.46
# ----------
# Stress tensor difference at iteration 0: 0.15709952525297763.
# R=0.66, friction=0.60
# Total instability: 0.95/Total differential instability: 0.22
# Average angle: 10.53
# Squared residuals: 3.94e-03
# ----------
# Stress tensor difference at iteration 1: 0.16077585670453323.
# R=0.70, friction=0.60
# Total instability: 0.91/Total differential instability: 0.21
# Average angle: 11.24
# Squared residuals: 3.42e-03
# ----------
# Stress tensor difference at iteration 2: 0.4796918365237092.
# R=0.49, friction=0.60
# Total instability: 0.83/Total differential instability: 0.12
# Average angle: 12.91
# Squared residuals: 6.62e-03
# ----------
# Stress tensor difference at iteration 3: 0.2290933680129797.
# R=0.57, friction=0.60
# Total instability: 0.96/Total differential instability: 0.22
# Average angle: 9.53
# Squared residuals: 3.54e-03
# ----------
# Stress tensor difference at iteration 4: 0.3469006673772966.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 5: 0.5546278525604841.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 6: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 7: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 8: 0.5546278061156524.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 9: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 10: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 11: 0.5546278061156524.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 12: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 13: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 14: 0.5546278061156524.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 15: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 16: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# ----------
# Stress tensor difference at iteration 17: 0.5546278061156524.
# R=0.48, friction=0.60
# Total instability: 0.82/Total differential instability: 0.11
# Average angle: 12.69
# Squared residuals: 6.13e-03
# ----------
# Stress tensor difference at iteration 18: 0.25669266860262047.
# R=0.56, friction=0.60
# Total instability: 0.96/Total differential instability: 0.23
# Average angle: 9.42
# Squared residuals: 3.45e-03
# ----------
# Stress tensor difference at iteration 19: 0.35460400865855585.
# R=0.68, friction=0.60
# Total instability: 0.92/Total differential instability: 0.24
# Average angle: 10.83
# Squared residuals: 3.24e-03
# Did not converge, return best (R=0.68)
# Final results:
# Stress tensor:
#  [[ 0.21383199 -0.32665747 -0.29173034]
#  [-0.32665747  0.33244765 -0.28434977]
#  [-0.29173034 -0.28434977 -0.54627967]]
# Shape ratio: 0.68
# Noise level 0, Linear iterative and failure criterion inversion...
# -------- 1/5 ----------
# Initial shape ratio: 0.47
# ----------
# Stress tensor difference at iteration 0: 0.4381061566075377.
# R=0.86, friction=0.60
# Total instability: 0.95/Total differential instability: 0.25
# Average angle: 5.31
# Squared residuals: 3.31e-04
# ----------
# Stress tensor difference at iteration 1: 0.7286811673386745.
# R=0.43, friction=0.60
# Total instability: 0.90/Total differential instability: 0.30
# Average angle: 8.22
# Squared residuals: 3.65e-03
# ----------
# Stress tensor difference at iteration 2: 0.7110865451972701.
# R=0.45, friction=0.60
# Total instability: 0.90/Total differential instability: 0.15
# Average angle: 7.50
# Squared residuals: 1.61e-03
# ----------
# Stress tensor difference at iteration 3: 0.7185503504489961.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.36
# Average angle: 0.00
# Squared residuals: 1.53e-14
# ----------
# Stress tensor difference at iteration 4: 1.0258684128527276.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 5: 1.0302696175355857.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 6: 0.7006184166088711.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: 0.00
# Squared residuals: 1.16e-14
# ----------
# Stress tensor difference at iteration 7: 1.0258681322881074.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 8: 1.030269617535594.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 9: 0.7006186001295573.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: 0.00
# Squared residuals: 8.97e-15
# ----------
# Stress tensor difference at iteration 10: 1.0258678981695335.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 11: 1.0302696175356014.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 12: 0.7006187532694956.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: 0.00
# Squared residuals: 7.16e-15
# ----------
# Stress tensor difference at iteration 13: 1.0258677028080767.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 14: 1.0302696175356076.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 15: 0.7006188810580278.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: nan
# Squared residuals: 5.90e-15
# ----------
# Stress tensor difference at iteration 16: 1.0258675397876817.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 17: 1.0302696175356127.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 18: 0.7006189876919228.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: nan
# Squared residuals: 5.02e-15
# ----------
# Stress tensor difference at iteration 19: 1.025867403754445.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# Did not converge, return best (R=0.70)
# -------- 2/5 ----------
# Initial shape ratio: 0.47
# ----------
# Stress tensor difference at iteration 0: 0.44634730854554766.
# R=0.85, friction=0.60
# Total instability: 0.95/Total differential instability: 0.24
# Average angle: 5.37
# Squared residuals: 3.41e-04
# ----------
# Stress tensor difference at iteration 1: 0.7445347168865755.
# R=0.46, friction=0.60
# Total instability: 0.91/Total differential instability: 0.30
# Average angle: 7.10
# Squared residuals: 2.73e-03
# ----------
# Stress tensor difference at iteration 2: 0.8070856190626841.
# R=0.43, friction=0.60
# Total instability: 0.88/Total differential instability: 0.13
# Average angle: 7.36
# Squared residuals: 1.57e-03
# ----------
# Stress tensor difference at iteration 3: 0.7487403218172354.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.37
# Average angle: 0.00
# Squared residuals: 1.54e-14
# ----------
# Stress tensor difference at iteration 4: 1.0258684257369102.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 5: 1.0302696175355852.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 6: 0.7006184081811779.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: 0.00
# Squared residuals: 1.17e-14
# ----------
# Stress tensor difference at iteration 7: 1.0258681430393786.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 8: 1.030269617535594.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 9: 0.7006185930970176.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: 0.00
# Squared residuals: 9.06e-15
# ----------
# Stress tensor difference at iteration 10: 1.0258679071409869.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 11: 1.0302696175356012.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 12: 0.700618747401151.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: 0.00
# Squared residuals: 7.22e-15
# ----------
# Stress tensor difference at iteration 13: 1.025867710294353.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 14: 1.0302696175356074.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 15: 0.700618876161153.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: 0.00
# Squared residuals: 5.95e-15
# ----------
# Stress tensor difference at iteration 16: 1.0258675460346443.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 17: 1.030269617535612.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 18: 0.7006189836056965.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: 0.00
# Squared residuals: 5.05e-15
# ----------
# Stress tensor difference at iteration 19: 1.0258674089672564.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# Did not converge, return best (R=0.70)
# -------- 3/5 ----------
# Initial shape ratio: 0.48
# ----------
# Stress tensor difference at iteration 0: 0.4217905581476943.
# R=0.86, friction=0.60
# Total instability: 0.95/Total differential instability: 0.24
# Average angle: 5.46
# Squared residuals: 3.48e-04
# ----------
# Stress tensor difference at iteration 1: 0.728498023423891.
# R=0.43, friction=0.60
# Total instability: 0.90/Total differential instability: 0.30
# Average angle: 8.22
# Squared residuals: 3.65e-03
# ----------
# Stress tensor difference at iteration 2: 0.7110865433678156.
# R=0.45, friction=0.60
# Total instability: 0.90/Total differential instability: 0.15
# Average angle: 7.50
# Squared residuals: 1.61e-03
# ----------
# Stress tensor difference at iteration 3: 0.7185503379324434.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.36
# Average angle: 0.00
# Squared residuals: 1.54e-14
# ----------
# Stress tensor difference at iteration 4: 1.02586842586394.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 5: 1.030269617535585.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 6: 0.7006184080980864.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: 0.00
# Squared residuals: 1.17e-14
# ----------
# Stress tensor difference at iteration 7: 1.0258681431453789.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 8: 1.0302696175355943.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 9: 0.7006185930276816.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: 0.00
# Squared residuals: 9.06e-15
# ----------
# Stress tensor difference at iteration 10: 1.0258679072294397.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 11: 1.030269617535601.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 12: 0.700618747343293.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: 0.00
# Squared residuals: 7.22e-15
# ----------
# Stress tensor difference at iteration 13: 1.0258677103681626.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 14: 1.0302696175356072.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 15: 0.7006188761128731.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: nan
# Squared residuals: 5.95e-15
# ----------
# Stress tensor difference at iteration 16: 1.0258675460962354.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 17: 1.0302696175356125.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 18: 0.7006189835654091.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: 0.00
# Squared residuals: 5.05e-15
# ----------
# Stress tensor difference at iteration 19: 1.0258674090186513.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# Did not converge, return best (R=0.70)
# -------- 4/5 ----------
# Initial shape ratio: 0.46
# ----------
# Stress tensor difference at iteration 0: 0.46061250852127267.
# R=0.86, friction=0.60
# Total instability: 0.95/Total differential instability: 0.24
# Average angle: 5.31
# Squared residuals: 3.31e-04
# ----------
# Stress tensor difference at iteration 1: 0.7286811673386745.
# R=0.43, friction=0.60
# Total instability: 0.90/Total differential instability: 0.30
# Average angle: 8.22
# Squared residuals: 3.65e-03
# ----------
# Stress tensor difference at iteration 2: 0.7110865451972701.
# R=0.45, friction=0.60
# Total instability: 0.90/Total differential instability: 0.15
# Average angle: 7.50
# Squared residuals: 1.61e-03
# ----------
# Stress tensor difference at iteration 3: 0.7185503504489961.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.36
# Average angle: 0.00
# Squared residuals: 1.53e-14
# ----------
# Stress tensor difference at iteration 4: 1.0258684128527276.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 5: 1.0302696175355857.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 6: 0.7006184166088711.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: 0.00
# Squared residuals: 1.16e-14
# ----------
# Stress tensor difference at iteration 7: 1.0258681322881074.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 8: 1.030269617535594.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 9: 0.7006186001295573.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: 0.00
# Squared residuals: 8.97e-15
# ----------
# Stress tensor difference at iteration 10: 1.0258678981695335.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 11: 1.0302696175356014.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 12: 0.7006187532694956.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: 0.00
# Squared residuals: 7.16e-15
# ----------
# Stress tensor difference at iteration 13: 1.0258677028080767.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 14: 1.0302696175356076.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 15: 0.7006188810580278.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: nan
# Squared residuals: 5.90e-15
# ----------
# Stress tensor difference at iteration 16: 1.0258675397876817.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 17: 1.0302696175356127.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 18: 0.7006189876919228.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: nan
# Squared residuals: 5.02e-15
# ----------
# Stress tensor difference at iteration 19: 1.025867403754445.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# Did not converge, return best (R=0.70)
# -------- 5/5 ----------
# Initial shape ratio: 0.45
# ----------
# Stress tensor difference at iteration 0: 0.4694057269182984.
# R=0.86, friction=0.60
# Total instability: 0.95/Total differential instability: 0.25
# Average angle: 5.31
# Squared residuals: 3.31e-04
# ----------
# Stress tensor difference at iteration 1: 0.7286811673386745.
# R=0.43, friction=0.60
# Total instability: 0.90/Total differential instability: 0.30
# Average angle: 8.22
# Squared residuals: 3.65e-03
# ----------
# Stress tensor difference at iteration 2: 0.7110865451972701.
# R=0.45, friction=0.60
# Total instability: 0.90/Total differential instability: 0.15
# Average angle: 7.50
# Squared residuals: 1.61e-03
# ----------
# Stress tensor difference at iteration 3: 0.7185503504489961.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.36
# Average angle: 0.00
# Squared residuals: 1.53e-14
# ----------
# Stress tensor difference at iteration 4: 1.0258684128527276.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 5: 1.0302696175355857.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 6: 0.7006184166088711.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: 0.00
# Squared residuals: 1.16e-14
# ----------
# Stress tensor difference at iteration 7: 1.0258681322881074.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 8: 1.030269617535594.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 9: 0.7006186001295573.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: 0.00
# Squared residuals: 8.97e-15
# ----------
# Stress tensor difference at iteration 10: 1.0258678981695335.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 11: 1.0302696175356014.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 12: 0.7006187532694956.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: 0.00
# Squared residuals: 7.16e-15
# ----------
# Stress tensor difference at iteration 13: 1.0258677028080767.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 14: 1.0302696175356076.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 15: 0.7006188810580278.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: nan
# Squared residuals: 5.90e-15
# ----------
# Stress tensor difference at iteration 16: 1.0258675397876817.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# ----------
# Stress tensor difference at iteration 17: 1.0302696175356127.
# R=0.44, friction=0.60
# Total instability: 0.96/Total differential instability: 0.30
# Average angle: 7.26
# Squared residuals: 1.98e-03
# ----------
# Stress tensor difference at iteration 18: 0.7006189876919228.
# R=0.70, friction=0.60
# Total instability: 0.93/Total differential instability: 0.38
# Average angle: nan
# Squared residuals: 5.02e-15
# ----------
# Stress tensor difference at iteration 19: 1.025867403754445.
# R=0.38, friction=0.60
# Total instability: 0.83/Total differential instability: 0.10
# Average angle: 10.20
# Squared residuals: 5.31e-03
# Did not converge, return best (R=0.70)
# Final results:
# Stress tensor:
#  [[ 0.14927723 -0.44783196 -0.3410246 ]
#  [-0.44783196  0.14927788 -0.341024  ]
#  [-0.3410246  -0.341024   -0.2985551 ]]
# Shape ratio: 0.70
# Noise level 0, linear inversion (bootstrapping)...
# ---------- Bootstrapping 1/1000 ----------
# ---------- Bootstrapping 101/1000 ----------
# ---------- Bootstrapping 201/1000 ----------
# ---------- Bootstrapping 301/1000 ----------
# ---------- Bootstrapping 401/1000 ----------
# ---------- Bootstrapping 501/1000 ----------
# ---------- Bootstrapping 601/1000 ----------
# ---------- Bootstrapping 701/1000 ----------
# ---------- Bootstrapping 801/1000 ----------
# ---------- Bootstrapping 901/1000 ----------
# Noise level 0, Linear iterative inversion (bootstrapping)...
# ---------- Bootstrapping 1/1000 ----------
# ---------- Bootstrapping 101/1000 ----------
# ---------- Bootstrapping 201/1000 ----------
# ---------- Bootstrapping 301/1000 ----------
# ---------- Bootstrapping 401/1000 ----------
# ---------- Bootstrapping 501/1000 ----------
# ---------- Bootstrapping 601/1000 ----------
# ---------- Bootstrapping 701/1000 ----------
# ---------- Bootstrapping 801/1000 ----------
# ---------- Bootstrapping 901/1000 ----------
# Noise level 0, failure criterion inversion (bootstrapping)...
# ---------- Bootstrapping 1/1000 ----------
# ---------- Bootstrapping 101/1000 ----------
# ---------- Bootstrapping 201/1000 ----------
# ---------- Bootstrapping 301/1000 ----------
# ---------- Bootstrapping 401/1000 ----------
# ---------- Bootstrapping 501/1000 ----------
# ---------- Bootstrapping 601/1000 ----------
# ---------- Bootstrapping 701/1000 ----------
# ---------- Bootstrapping 801/1000 ----------
# ---------- Bootstrapping 901/1000 ----------
# Noise level 0, non-linear iterative and failure criterion inversion (bootstrapping)...
# ---------- Bootstrapping 1/1000 ----------
# ---------- Bootstrapping 101/1000 ----------
# ---------- Bootstrapping 201/1000 ----------
# ---------- Bootstrapping 301/1000 ----------
# ---------- Bootstrapping 401/1000 ----------
# ---------- Bootstrapping 501/1000 ----------
# ---------- Bootstrapping 601/1000 ----------
# ---------- Bootstrapping 701/1000 ----------
# ---------- Bootstrapping 801/1000 ----------
# ---------- Bootstrapping 901/1000 ----------
# Noise level 1, linear inversion...
# Noise level 1, linear iterative inversion...
# Noise level 1, failure criterion inversion...
# -------- 1/5 ----------
# Initial shape ratio: 0.46
# ----------
# Stress tensor difference at iteration 0: 0.11659574921083461.
# R=0.61, friction=0.60
# Total instability: 0.95/Total differential instability: 0.22
# Average angle: 10.52
# Squared residuals: 4.72e-03
# ----------
# Stress tensor difference at iteration 1: 0.14670639613913172.
# R=0.71, friction=0.60
# Total instability: 0.92/Total differential instability: 0.22
# Average angle: 12.40
# Squared residuals: 4.56e-03
# ----------
# Stress tensor difference at iteration 2: 0.21359823377550607.
# R=0.54, friction=0.60
# Total instability: 0.86/Total differential instability: 0.14
# Average angle: 13.64
# Squared residuals: 8.67e-03
# ----------
# Stress tensor difference at iteration 3: 0.08429081261484968.
# R=0.63, friction=0.60
# Total instability: 0.95/Total differential instability: 0.21
# Average angle: 10.89
# Squared residuals: 4.89e-03
# ----------
# Stress tensor difference at iteration 4: 0.1022088949888846.
# R=0.72, friction=0.60
# Total instability: 0.92/Total differential instability: 0.21
# Average angle: 12.51
# Squared residuals: 4.73e-03
# ----------
# Stress tensor difference at iteration 5: 0.16517328942370896.
# R=0.56, friction=0.60
# Total instability: 0.87/Total differential instability: 0.14
# Average angle: 13.56
# Squared residuals: 8.43e-03
# ----------
# Stress tensor difference at iteration 6: 0.08291774036582154.
# R=0.67, friction=0.60
# Total instability: 0.94/Total differential instability: 0.20
# Average angle: 11.21
# Squared residuals: 4.67e-03
# ----------
# Stress tensor difference at iteration 7: 0.05534857625934643.
# R=0.72, friction=0.60
# Total instability: 0.91/Total differential instability: 0.20
# Average angle: 12.51
# Squared residuals: 4.73e-03
# ----------
# Stress tensor difference at iteration 8: 0.16517328942370896.
# R=0.56, friction=0.60
# ...
# Average angle: 14.47
# Squared residuals: 5.20e-03
# ----------
# Stress tensor difference at iteration 15: 0.24999367189136004.
# R=0.85, friction=0.60
# Total instability: 0.92/Total differential instability: 0.31
# Average angle: 14.09
# Squared residuals: 4.76e-03
# ----------
# Stress tensor difference at iteration 16: 0.5216596768391804.
# R=0.47, friction=0.60
# Total instability: 0.88/Total differential instability: 0.23
# Average angle: 14.26
# Squared residuals: 1.08e-02
# ----------
# Stress tensor difference at iteration 17: 0.41842490915032937.
# R=0.58, friction=0.60
# Total instability: 0.94/Total differential instability: 0.22
# Average angle: 14.47
# Squared residuals: 5.20e-03
# ----------
# Stress tensor difference at iteration 18: 0.24999367189136004.
# R=0.85, friction=0.60
# Total instability: 0.92/Total differential instability: 0.31
# Average angle: 14.09
# Squared residuals: 4.76e-03
# ----------
# Stress tensor difference at iteration 19: 0.5216596768391804.
# R=0.47, friction=0.60
# Total instability: 0.88/Total differential instability: 0.23
# Average angle: 14.26
# Squared residuals: 1.08e-02
# Did not converge, return best (R=0.81)
# -------- 3/5 ----------
# Initial shape ratio: 0.53
# ----------
# Stress tensor difference at iteration 0: 0.2970488247788565.
# R=0.77, friction=0.60
# Total instability: 0.95/Total differential instability: 0.24
# Average angle: 14.09
# Squared residuals: 3.83e-03
# ----------
# Stress tensor difference at iteration 1: 0.1519337001019383.
# R=0.69, friction=0.60
# Total instability: 0.90/Total differential instability: 0.29
# Average angle: 13.91
# Squared residuals: 7.62e-03
# ----------
# Stress tensor difference at iteration 2: 0.1592244277033679.
# R=0.78, friction=0.60
# Total instability: 0.88/Total differential instability: 0.17
# Average angle: 16.44
# Squared residuals: 6.68e-03
# ----------
# Stress tensor difference at iteration 3: 0.05836023226557189.
# R=0.81, friction=0.60
# Total instability: 0.92/Total differential instability: 0.27
# Average angle: 14.02
# Squared residuals: 5.56e-03
# ----------
# Stress tensor difference at iteration 4: 0.26919112804178463.
# R=0.56, friction=0.60
# Total instability: 0.89/Total differential instability: 0.23
# Average angle: 15.57
# Squared residuals: 1.18e-02
# ----------
# Stress tensor difference at iteration 5: 0.2621335872097691.
# R=0.67, friction=0.60
# Total instability: 0.93/Total differential instability: 0.20
# Average angle: 15.04
# Squared residuals: 6.19e-03
# ----------
# Stress tensor difference at iteration 6: 0.14376035402414178.
# R=0.85, friction=0.60
# Total instability: 0.92/Total differential instability: 0.29
# Average angle: 14.04
# Squared residuals: 4.63e-03
# ----------
# Stress tensor difference at iteration 7: 0.4322496293789036.
# R=0.50, friction=0.60
# Total instability: 0.89/Total differential instability: 0.24
# Average angle: 14.76
# Squared residuals: 1.12e-02
# ----------
# Stress tensor difference at iteration 8: 0.35460256387013883.
# R=0.61, friction=0.60
# Total instability: 0.93/Total differential instability: 0.20
# Average angle: 14.74
# Squared residuals: 5.67e-03
# ----------
# Stress tensor difference at iteration 9: 0.21193114116967707.
# R=0.86, friction=0.60
# Total instability: 0.92/Total differential instability: 0.30
# Average angle: 14.16
# Squared residuals: 4.66e-03
# ----------
# Stress tensor difference at iteration 10: 0.4879458733480585.
# R=0.49, friction=0.60
# Total instability: 0.88/Total differential instability: 0.24
# Average angle: 14.60
# Squared residuals: 1.12e-02
# ----------
# Stress tensor difference at iteration 11: 0.39453884517951604.
# R=0.59, friction=0.60
# Total instability: 0.93/Total differential instability: 0.21
# Average angle: 14.70
# Squared residuals: 5.25e-03
# ----------
# Stress tensor difference at iteration 12: 0.24106483702240228.
# R=0.85, friction=0.60
# Total instability: 0.92/Total differential instability: 0.31
# Average angle: 14.09
# Squared residuals: 4.76e-03
# ----------
# Stress tensor difference at iteration 13: 0.5216598279611584.
# R=0.47, friction=0.60
# Total instability: 0.88/Total differential instability: 0.23
# Average angle: 14.26
# Squared residuals: 1.08e-02
# ----------
# Stress tensor difference at iteration 14: 0.4184248784679636.
# R=0.58, friction=0.60
# Total instability: 0.94/Total differential instability: 0.22
# Average angle: 14.47
# Squared residuals: 5.20e-03
# ----------
# Stress tensor difference at iteration 15: 0.2499936990053957.
# R=0.85, friction=0.60
# Total instability: 0.92/Total differential instability: 0.31
# Average angle: 14.09
# Squared residuals: 4.76e-03
# ----------
# Stress tensor difference at iteration 16: 0.5216598279611584.
# R=0.47, friction=0.60
# Total instability: 0.88/Total differential instability: 0.23
# Average angle: 14.26
# Squared residuals: 1.08e-02
# ----------
# Stress tensor difference at iteration 17: 0.4184248784679636.
# R=0.58, friction=0.60
# Total instability: 0.94/Total differential instability: 0.22
# Average angle: 14.47
# Squared residuals: 5.20e-03
# ----------
# Stress tensor difference at iteration 18: 0.2499936990053957.
# R=0.85, friction=0.60
# Total instability: 0.92/Total differential instability: 0.31
# Average angle: 14.09
# Squared residuals: 4.76e-03
# ----------
# Stress tensor difference at iteration 19: 0.5216598279611584.
# R=0.47, friction=0.60
# Total instability: 0.88/Total differential instability: 0.23
# Average angle: 14.26
# Squared residuals: 1.08e-02
# Did not converge, return best (R=0.77)
# -------- 4/5 ----------
# Initial shape ratio: 0.52
# ----------
# Stress tensor difference at iteration 0: 0.32956811411347775.
# R=0.81, friction=0.60
# Total instability: 0.95/Total differential instability: 0.24
# Average angle: 14.37
# Squared residuals: 3.89e-03
# ----------
# Stress tensor difference at iteration 1: 0.23139045504999595.
# R=0.60, friction=0.60
# Total instability: 0.90/Total differential instability: 0.28
# Average angle: 14.73
# Squared residuals: 9.68e-03
# ----------
# Stress tensor difference at iteration 2: 0.21623065801198998.
# R=0.76, friction=0.60
# Total instability: 0.90/Total differential instability: 0.18
# Average angle: 15.03
# Squared residuals: 5.94e-03
# ----------
# Stress tensor difference at iteration 3: 0.07447962431826864.
# R=0.81, friction=0.60
# Total instability: 0.92/Total differential instability: 0.27
# Average angle: 14.02
# Squared residuals: 5.56e-03
# ----------
# Stress tensor difference at iteration 4: 0.2691910130928835.
# R=0.56, friction=0.60
# Total instability: 0.89/Total differential instability: 0.23
# Average angle: 15.57
# Squared residuals: 1.18e-02
# ----------
# Stress tensor difference at iteration 5: 0.2621336064478047.
# R=0.67, friction=0.60
# Total instability: 0.93/Total differential instability: 0.20
# Average angle: 15.04
# Squared residuals: 6.19e-03
# ----------
# Stress tensor difference at iteration 6: 0.14376035161047937.
# R=0.85, friction=0.60
# Total instability: 0.92/Total differential instability: 0.29
# Average angle: 14.04
# Squared residuals: 4.63e-03
# ----------
# Stress tensor difference at iteration 7: 0.432249684923062.
# R=0.50, friction=0.60
# Total instability: 0.89/Total differential instability: 0.24
# Average angle: 14.76
# Squared residuals: 1.12e-02
# ----------
# Stress tensor difference at iteration 8: 0.3546025815442717.
# R=0.61, friction=0.60
# Total instability: 0.93/Total differential instability: 0.20
# Average angle: 14.74
# Squared residuals: 5.67e-03
# ----------
# Stress tensor difference at iteration 9: 0.21193114308315922.
# R=0.86, friction=0.60
# Total instability: 0.92/Total differential instability: 0.30
# Average angle: 14.16
# Squared residuals: 4.66e-03
# ----------
# Stress tensor difference at iteration 10: 0.4879459275371353.
# R=0.49, friction=0.60
# Total instability: 0.88/Total differential instability: 0.24
# Average angle: 14.60
# Squared residuals: 1.12e-02
# ----------
# Stress tensor difference at iteration 11: 0.394538869496087.
# R=0.59, friction=0.60
# Total instability: 0.93/Total differential instability: 0.21
# Average angle: 14.70
# Squared residuals: 5.25e-03
# ----------
# Stress tensor difference at iteration 12: 0.24106481290730614.
# R=0.85, friction=0.60
# Total instability: 0.92/Total differential instability: 0.31
# Average angle: 14.09
# Squared residuals: 4.76e-03
# ----------
# Stress tensor difference at iteration 13: 0.5216596768391804.
# R=0.47, friction=0.60
# Total instability: 0.88/Total differential instability: 0.23
# Average angle: 14.26
# Squared residuals: 1.08e-02
# ----------
# Stress tensor difference at iteration 14: 0.41842490915032937.
# R=0.58, friction=0.60
# Total instability: 0.94/Total differential instability: 0.22
# Average angle: 14.47
# Squared residuals: 5.20e-03
# ----------
# Stress tensor difference at iteration 15: 0.24999367189136004.
# R=0.85, friction=0.60
# Total instability: 0.92/Total differential instability: 0.31
# Average angle: 14.09
# Squared residuals: 4.76e-03
# ----------
# Stress tensor difference at iteration 16: 0.5216596768391804.
# R=0.47, friction=0.60
# Total instability: 0.88/Total differential instability: 0.23
# Average angle: 14.26
# Squared residuals: 1.08e-02
# ----------
# Stress tensor difference at iteration 17: 0.41842490915032937.
# R=0.58, friction=0.60
# Total instability: 0.94/Total differential instability: 0.22
# Average angle: 14.47
# Squared residuals: 5.20e-03
# ----------
# Stress tensor difference at iteration 18: 0.24999367189136004.
# R=0.85, friction=0.60
# Total instability: 0.92/Total differential instability: 0.31
# Average angle: 14.09
# Squared residuals: 4.76e-03
# ----------
# Stress tensor difference at iteration 19: 0.5216596768391804.
# R=0.47, friction=0.60
# Total instability: 0.88/Total differential instability: 0.23
# Average angle: 14.26
# Squared residuals: 1.08e-02
# Did not converge, return best (R=0.81)
# -------- 5/5 ----------
# Initial shape ratio: 0.52
# ----------
# Stress tensor difference at iteration 0: 0.32715676625040596.
# R=0.81, friction=0.60
# Total instability: 0.95/Total differential instability: 0.24
# Average angle: 14.37
# Squared residuals: 3.89e-03
# ----------
# Stress tensor difference at iteration 1: 0.23139045504999595.
# R=0.60, friction=0.60
# Total instability: 0.90/Total differential instability: 0.28
# Average angle: 14.73
# Squared residuals: 9.68e-03
# ----------
# Stress tensor difference at iteration 2: 0.21623065801198998.
# R=0.76, friction=0.60
# Total instability: 0.90/Total differential instability: 0.18
# Average angle: 15.03
# Squared residuals: 5.94e-03
# ----------
# Stress tensor difference at iteration 3: 0.07447962431826864.
# R=0.81, friction=0.60
# Total instability: 0.92/Total differential instability: 0.27
# Average angle: 14.02
# Squared residuals: 5.56e-03
# ----------
# Stress tensor difference at iteration 4: 0.2691910130928835.
# R=0.56, friction=0.60
# Total instability: 0.89/Total differential instability: 0.23
# Average angle: 15.57
# Squared residuals: 1.18e-02
# ----------
# Stress tensor difference at iteration 5: 0.2621336064478047.
# R=0.67, friction=0.60
# Total instability: 0.93/Total differential instability: 0.20
# Average angle: 15.04
# Squared residuals: 6.19e-03
# ----------
# Stress tensor difference at iteration 6: 0.14376035161047937.
# R=0.85, friction=0.60
# Total instability: 0.92/Total differential instability: 0.29
# Average angle: 14.04
# Squared residuals: 4.63e-03
# ----------
# Stress tensor difference at iteration 7: 0.432249684923062.
# R=0.50, friction=0.60
# Total instability: 0.89/Total differential instability: 0.24
# Average angle: 14.76
# Squared residuals: 1.12e-02
# ----------
# Stress tensor difference at iteration 8: 0.3546025815442717.
# R=0.61, friction=0.60
# Total instability: 0.93/Total differential instability: 0.20
# Average angle: 14.74
# Squared residuals: 5.67e-03
# ----------
# Stress tensor difference at iteration 9: 0.21193114308315922.
# R=0.86, friction=0.60
# Total instability: 0.92/Total differential instability: 0.30
# Average angle: 14.16
# Squared residuals: 4.66e-03
# ----------
# Stress tensor difference at iteration 10: 0.4879459275371353.
# R=0.49, friction=0.60
# Total instability: 0.88/Total differential instability: 0.24
# Average angle: 14.60
# Squared residuals: 1.12e-02
# ----------
# Stress tensor difference at iteration 11: 0.394538869496087.
# R=0.59, friction=0.60
# Total instability: 0.93/Total differential instability: 0.21
# Average angle: 14.70
# Squared residuals: 5.25e-03
# ----------
# Stress tensor difference at iteration 12: 0.24106481290730614.
# R=0.85, friction=0.60
# Total instability: 0.92/Total differential instability: 0.31
# Average angle: 14.09
# Squared residuals: 4.76e-03
# ----------
# Stress tensor difference at iteration 13: 0.5216596768391804.
# R=0.47, friction=0.60
# Total instability: 0.88/Total differential instability: 0.23
# Average angle: 14.26
# Squared residuals: 1.08e-02
# ----------
# Stress tensor difference at iteration 14: 0.41842490915032937.
# R=0.58, friction=0.60
# Total instability: 0.94/Total differential instability: 0.22
# Average angle: 14.47
# Squared residuals: 5.20e-03
# ----------
# Stress tensor difference at iteration 15: 0.24999367189136004.
# R=0.85, friction=0.60
# Total instability: 0.92/Total differential instability: 0.31
# Average angle: 14.09
# Squared residuals: 4.76e-03
# ----------
# Stress tensor difference at iteration 16: 0.5216596768391804.
# R=0.47, friction=0.60
# Total instability: 0.88/Total differential instability: 0.23
# Average angle: 14.26
# Squared residuals: 1.08e-02
# ----------
# Stress tensor difference at iteration 17: 0.41842490915032937.
# R=0.58, friction=0.60
# Total instability: 0.94/Total differential instability: 0.22
# Average angle: 14.47
# Squared residuals: 5.20e-03
# ----------
# Stress tensor difference at iteration 18: 0.24999367189136004.
# R=0.85, friction=0.60
# Total instability: 0.92/Total differential instability: 0.31
# Average angle: 14.09
# Squared residuals: 4.76e-03
# ----------
# Stress tensor difference at iteration 19: 0.5216596768391804.
# R=0.47, friction=0.60
# Total instability: 0.88/Total differential instability: 0.23
# Average angle: 14.26
# Squared residuals: 1.08e-02
# Did not converge, return best (R=0.81)
# Final results:
# Stress tensor:
#  [[ 0.22176409 -0.18079393 -0.4928419 ]
#  [-0.18079393  0.30812174 -0.10839945]
#  [-0.4928419  -0.10839945 -0.5298859 ]]
# Shape ratio: 0.81
# Noise level 2, linear inversion (bootstrapping)...
# ---------- Bootstrapping 1/1000 ----------
# ---------- Bootstrapping 101/1000 ----------
# ---------- Bootstrapping 201/1000 ----------
# ---------- Bootstrapping 301/1000 ----------
# ---------- Bootstrapping 401/1000 ----------
# ---------- Bootstrapping 501/1000 ----------
# ---------- Bootstrapping 601/1000 ----------
# ---------- Bootstrapping 701/1000 ----------
# ---------- Bootstrapping 801/1000 ----------
# ---------- Bootstrapping 901/1000 ----------
# Noise level 2, Linear iterative inversion (bootstrapping)...
# ---------- Bootstrapping 1/1000 ----------
# ---------- Bootstrapping 101/1000 ----------
# ---------- Bootstrapping 201/1000 ----------
# ---------- Bootstrapping 301/1000 ----------
# ---------- Bootstrapping 401/1000 ----------
# ---------- Bootstrapping 501/1000 ----------
# ---------- Bootstrapping 601/1000 ----------
# ---------- Bootstrapping 701/1000 ----------
# ---------- Bootstrapping 801/1000 ----------
# ---------- Bootstrapping 901/1000 ----------
# Noise level 2, failure criterion inversion (bootstrapping)...
# ---------- Bootstrapping 1/1000 ----------
# ---------- Bootstrapping 101/1000 ----------
# ---------- Bootstrapping 201/1000 ----------
# ---------- Bootstrapping 301/1000 ----------
# ---------- Bootstrapping 401/1000 ----------
# ---------- Bootstrapping 501/1000 ----------
# ---------- Bootstrapping 601/1000 ----------
# ---------- Bootstrapping 701/1000 ----------
# ---------- Bootstrapping 801/1000 ----------
# ---------- Bootstrapping 901/1000 ----------
# Noise level 2, non-linear iterative and failure criterion inversion (bootstrapping)...
# ---------- Bootstrapping 1/1000 ----------
# ---------- Bootstrapping 101/1000 ----------
# ---------- Bootstrapping 201/1000 ----------
# ---------- Bootstrapping 301/1000 ----------
# ---------- Bootstrapping 401/1000 ----------
# ---------- Bootstrapping 501/1000 ----------
# ---------- Bootstrapping 601/1000 ----------
# ---------- Bootstrapping 701/1000 ----------
# ---------- Bootstrapping 801/1000 ----------
# ---------- Bootstrapping 901/1000 ----------
# Done! The experiment ran in 9438.15 seconds

# %%
# save the results for future use (e.g. to play around with the plotting functions)
save_results(true_stress_tensor, inversion_output, f'./experiment{experiment}.h5')

# %%
# or read results from previously run experiment
true_stress_tensor, inversion_output = read_results(f'./experiment{experiment}.h5')

# %% [markdown]
# ## Plot the results
#
# Define plotting routines and use them to reproduce the figures shown in the paper.

# %%
# define plotting routines
def truncate_colormap(cmap, minval=0.0, maxval=1.0, n=100):
    from matplotlib.colors import LinearSegmentedColormap
    new_cmap = LinearSegmentedColormap.from_list(
        'trunc({n},{a:.2f},{b:.2f})'.format(n=cmap.name, a=minval, b=maxval),
        cmap(np.linspace(minval, maxval, n)))
    return new_cmap

def plot_inverted_stress_tensors(true_stress_tensor, inversion_output, axes=None, **kwargs):
    hist_kwargs = {}
    hist_kwargs['smoothing_sig'] = kwargs.get('smoothing_sig', 1)
    hist_kwargs['nbins'] = kwargs.get('nbins', 200)
    hist_kwargs['return_count'] = kwargs.get('return_count', True)
    hist_kwargs['confidence_intervals'] = kwargs.get('confidence_intervals', [95.])
    cmaps = ['Blues', 'Oranges', 'Greens', 'Reds']
    cmaps = [truncate_colormap(plt.get_cmap(cmap), minval=0., maxval=0.75) for cmap in cmaps]
    n_bootstraps = inversion_output['linear']['boot_principal_directions'][0, ...].shape[0]
    true_ps, true_pd = ILSI.utils_stress.stress_tensor_eigendecomposition(true_stress_tensor)
    true_R = ILSI.utils_stress.R_(true_ps)
    markers = ['o', 's', 'v']
    methods = ['linear', 'failure_criterion', 'iterative', 'iterative_failure_criterion']
    fig = plt.figure('inverted_stress_tensors', figsize=(18, 9))
    ax = fig.add_subplot(3, 4, 1, projection='stereonet')
    ax.set_title('True fault planes', pad=30)
    ax.plane(inversion_output['strikes'][:, 0, 0],
             inversion_output['dips'][:, 0, 0], color='k',
             lw=1.0)
    ax1 = fig.add_subplot(3, 4, 5, projection='stereonet')
    for i in range(3):
        az, pl = ILSI.utils_stress.get_bearing_plunge(true_pd[:, i])
        ax1.line(pl, az, marker=markers[i], markeredgecolor='k',
                 markeredgewidth=2, markerfacecolor='none',
                 markersize=20, label=r'True $\sigma_{{{:d}}}$: {:.1f}'u'\u00b0''|{:.1f}'u'\u00b0'.
                 format(i+1, az%360., pl))
    for method, cl, cmap in zip(['linear', 'iterative'], [_colors_[0], _colors_[2]], [cmaps[0], cmaps[2]]):
        exp = f'true_fp_{method}'
        R = ILSI.utils_stress.R_(inversion_output[exp]['principal_stresses'])
        for k in range(3):
            if k == 0:
                label = '{}, R={:.2f}, $\\vert{{\\Delta \\theta}}\\vert$={:.1f}'u'\u00b0'.\
                        format(method.capitalize(), R, inversion_output[exp]['misfit'])
            else:
                label = ''
            az, pl = ILSI.utils_stress.get_bearing_plunge(
                    inversion_output[exp]['principal_directions'][:, k])
            ax1.line(pl, az, marker=markers[k], markeredgecolor=cl, markerfacecolor='none',
                     markeredgewidth=2, markersize=15, label=label)
            boot_pd_stereo = np.zeros((n_bootstraps, 2), dtype=np.float32)
            for b in range(n_bootstraps):
                boot_pd_stereo[b, :] = ILSI.utils_stress.get_bearing_plunge(
                        inversion_output[exp]['boot_principal_directions'][b, :, k])
            count, lons_g, lats_g, levels = ILSI.utils_stress.get_CI_levels(
                    boot_pd_stereo[:, 0], boot_pd_stereo[:, 1], **hist_kwargs)
            ax1.contour(lons_g, lats_g, count, levels=levels,
                        linestyles=['solid', 'dashed', 'dashdot'][k],
                        vmin=0., colors=cl)
    fake_handle = [ax1.plot([], [], marker='', ls='')[0]]
    title_label = ['True stress tensor (R={:.2f}):'.format(true_R)]
    handles, labels = ax1.get_legend_handles_labels()
    plt.legend(fake_handle+handles, title_label+labels, loc='upper left', bbox_to_anchor=(-0.1, -0.15))
    axes = [ax1]
    titles = ['Noise-free', 'Low Noise', 'High Noise']
    for i, title in enumerate(titles):
        ax1 = fig.add_subplot(3, 4, 2+i,projection='stereonet')
        ax1.set_title(title, pad=30)
        ax1.plane(inversion_output['strikes'][:, i, 0],
                  inversion_output['dips'][:, i, 0], color='k',
                  lw=1.0)
        ax1.plane(inversion_output['strikes'][:, i, 1],
                  inversion_output['dips'][:, i, 1], color='dimgray',
                  lw=0.65)
        ax = fig.add_subplot(3, 4, 6+i, projection='stereonet')
        for j, method in enumerate(methods):
            R = ILSI.utils_stress.R_(inversion_output[method]['principal_stresses'][i, ...])
            for k in range(3):
                az, pl = ILSI.utils_stress.get_bearing_plunge(true_pd[:, k])
                ax.line(pl, az, marker=markers[k], markeredgecolor='k', markerfacecolor='none',
                        markeredgewidth=2, zorder=1, markersize=20)
                if k == 0:
                    label = '{}:\nR={:.2f}, $\\vert{{\\Delta \\theta}}\\vert$={:.1f}'u'\u00b0'.\
                            format(method.replace('_', ' ').capitalize(), R, inversion_output[method]['misfit'][i])
                else:
                    label = ''
                az, pl = ILSI.utils_stress.get_bearing_plunge(
                        inversion_output[method]['principal_directions'][i, :, k])
                ax.line(pl, az, marker=markers[k], markeredgecolor=_colors_[j], markerfacecolor='none',
                        markeredgewidth=2, markersize=15, label=label, zorder=2)
                boot_pd_stereo = np.zeros((n_bootstraps, 2), dtype=np.float32)
                for b in range(n_bootstraps):
                    boot_pd_stereo[b, :] = ILSI.utils_stress.get_bearing_plunge(
                            inversion_output[method]['boot_principal_directions'][i, b, :, k])
                count, lons_g, lats_g, levels = ILSI.utils_stress.get_CI_levels(
                        boot_pd_stereo[:, 0], boot_pd_stereo[:, 1], **hist_kwargs)
                ax.contour(lons_g, lats_g, count,
                           levels=levels, vmin=0.,
                           linestyles=['solid', 'dashed', 'dashdot'][k],
                           colors=_colors_[j])
        ax.legend(loc='upper left', bbox_to_anchor=(-0.1, -0.15))
        axes.append(ax)
    plt.subplots_adjust(top=0.88, bottom=0.11,
                        left=0.05, right=0.95,
                        hspace=0.4, wspace=0.4)
    return fig

def plot_shape_ratios(true_stress_tensor, inversion_output):
    true_ps, true_pd = ILSI.utils_stress.stress_tensor_eigendecomposition(true_stress_tensor)
    true_R = ILSI.utils_stress.R_(true_ps)
    fig = plt.figure('shape_ratios', figsize=(18, 9))
    titles = ['Noise-free', 'Low Noise', 'High Noise']
    methods = ['linear', 'failure_criterion', 'iterative', 'iterative_failure_criterion']
    n_bootstraps = inversion_output['linear']['boot_stress_tensor'].shape[1]
    ax = fig.add_subplot(3, 4, 1)
    for exp, cl in zip(['true_fp_linear', 'true_fp_iterative'], [_colors_[0], _colors_[2]]):
        Rs = np.zeros(n_bootstraps, dtype=np.float32)
        for b in range(n_bootstraps):
            Rs[b] = ILSI.utils_stress.R_(inversion_output[exp]['boot_principal_stresses'][b, :])
        ax.hist(Rs, range=(0., 1.), bins=20, lw=2.5, color=cl, histtype='step')
        ax.axvline(true_R, color='k')
        ax.set_xlabel('Shape Ratio')
        ax.set_ylabel('Count')
    for i, title in enumerate(titles):
        ax = fig.add_subplot(3, 4, 2+i)
        for j, method in enumerate(methods):
            R = ILSI.utils_stress.R_(inversion_output[method]['principal_stresses'][i, ...])
            Rs = np.zeros(n_bootstraps, dtype=np.float32)
            for b in range(n_bootstraps):
                Rs[b] = ILSI.utils_stress.R_(inversion_output[method]['boot_principal_stresses'][i, b, :])
            ax.hist(Rs, range=(0., 1.), bins=20, lw=2.5, color=_colors_[j], histtype='step')
            if j == 3:
                ax.hist(Rs, range=(0., 1.), bins=20, lw=2.5, color=_colors_[j], alpha=0.4)
            ax.axvline(true_R, color='k')
            ax.set_xlabel('Shape Ratio')
            ax.set_ylabel('Count')
    plt.subplots_adjust(top=0.93, bottom=0.11,
                        left=0.06, right=0.95,
                        hspace=0.25, wspace=0.4)
    return fig


def plot_shear_magnitudes(true_stress_tensor, inversion_output, axes=None):
    normals, slips = ILSI.utils_stress.normal_slip_vectors(
            inversion_output['strikes'][..., 0],
            inversion_output['dips'][..., 0],
            inversion_output['rakes'][..., 0])
    _, _, true_shear = ILSI.utils_stress.compute_traction(
            true_stress_tensor, normals[:, :, 0].T)
    _, _, true_fp_linear_shear = ILSI.utils_stress.compute_traction(
            inversion_output['true_fp_linear']['stress_tensor'], normals[:, :, 0].T)
    _, _, true_fp_iterative_shear = ILSI.utils_stress.compute_traction(
            inversion_output['true_fp_iterative']['stress_tensor'], normals[:, :, 0].T)
    fig = plt.figure('shear', figsize=(18, 9))
    ax1 = fig.add_subplot(2, 4, 1)
    ax1.scatter(np.sqrt(np.sum(true_shear**2, axis=-1)),
                np.sqrt(np.sum(true_fp_linear_shear**2, axis=-1)),
                color=_colors_[0], label='Naive')
    ax1.scatter(np.sqrt(np.sum(true_shear**2, axis=-1)),
                np.sqrt(np.sum(true_fp_iterative_shear**2, axis=-1)),
                color=_colors_[2], label='Iterative')
    ax1.set_aspect('equal')
    ax1.legend(loc='upper left')
    ax1.set_xlabel('True shear stress $\\vert \\tau \\vert$')
    ax1.set_ylabel('Predicted shear stress $\\vert \\tilde{\\tau} \\vert$')
    # -------------------
    ax2 = fig.add_subplot(2, 4, 5)
    ax2.hist(np.sqrt(np.sum(true_shear**2, axis=-1)), range=(0., 1.0), bins=20, color='k', histtype='step', lw=2.5, label='True')
    ax2.hist(np.sqrt(np.sum(true_fp_linear_shear**2, axis=-1)), range=(0., 1.0), bins=20, color=_colors_[0], alpha=0.5, label='Linear')
    ax2.hist(np.sqrt(np.sum(true_fp_iterative_shear**2, axis=-1)), range=(0., 1.0), bins=20, color=_colors_[2], alpha=0.5, label='Iterative')
    ax2.set_ylabel('Count')
    ax2.set_xlabel('Shear stress $\\vert \\tau \\vert$')
    ax2.legend(loc='best')
    # -------------------
    plt.subplots_adjust(top=0.98, bottom=0.15, left=0.10, right=0.98)
    return fig

# %%
# plot stress directions
# %matplotlib qt
fig1 = plot_inverted_stress_tensors(true_stress_tensor, inversion_output, smoothing_sig=2)

# %%
# plot shape ratios
fig2 = plot_shape_ratios(true_stress_tensor, inversion_output)

# %%
# plot resolved shear stress magnitudes
fig3 = plot_shear_magnitudes(true_stress_tensor, inversion_output)
